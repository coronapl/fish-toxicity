# %%
import pandas as pd

FEATURES = ['CIC0', 'SM1_Dz(Z)', 'GATS1i', 'NdsCH', 'NdssC', 'MLOGP']
TARGET = ['LC50']

df = pd.read_csv('data.csv', sep=';')
df.columns = FEATURES + TARGET
df.head()
# Out:
#     CIC0  SM1_Dz(Z)  GATS1i  NdsCH  NdssC  MLOGP   LC50
# 0  2.189      0.580   0.863      0      0  1.348  3.115
# 1  2.125      0.638   0.831      0      0  1.348  3.531
# 2  3.027      0.331   1.472      1      0  1.807  3.510
# 3  2.094      0.827   0.860      0      0  1.886  5.390
# 4  3.222      0.331   2.177      0      0  0.706  1.819

# %%
df.max(axis=0)
# Out:
# CIC0         5.926
# SM1_Dz(Z)    2.171
# GATS1i       2.920
# NdsCH        4.000
# NdssC        6.000
# MLOGP        6.515
# LC50         9.612
# dtype: float64

# %%
df.min(axis=0)
# Out:
# CIC0         0.667
# SM1_Dz(Z)    0.000
# GATS1i       0.396
# NdsCH        0.000
# NdssC        0.000
# MLOGP       -2.884
# LC50         0.053
# dtype: float64

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='CIC0', ylabel='CIC0'>,
#         <Axes: xlabel='SM1_Dz(Z)', ylabel='CIC0'>,
#         <Axes: xlabel='GATS1i', ylabel='CIC0'>,
#         <Axes: xlabel='NdsCH', ylabel='CIC0'>,
#         <Axes: xlabel='NdssC', ylabel='CIC0'>,
#         <Axes: xlabel='MLOGP', ylabel='CIC0'>,
#         <Axes: xlabel='LC50', ylabel='CIC0'>],
#        [<Axes: xlabel='CIC0', ylabel='SM1_Dz(Z)'>,
#         <Axes: xlabel='SM1_Dz(Z)', ylabel='SM1_Dz(Z)'>,
#         <Axes: xlabel='GATS1i', ylabel='SM1_Dz(Z)'>,
#         <Axes: xlabel='NdsCH', ylabel='SM1_Dz(Z)'>,
#         <Axes: xlabel='NdssC', ylabel='SM1_Dz(Z)'>,
#         <Axes: xlabel='MLOGP', ylabel='SM1_Dz(Z)'>,
#         <Axes: xlabel='LC50', ylabel='SM1_Dz(Z)'>],
#        [<Axes: xlabel='CIC0', ylabel='GATS1i'>,
#         <Axes: xlabel='SM1_Dz(Z)', ylabel='GATS1i'>,
#         <Axes: xlabel='GATS1i', ylabel='GATS1i'>,
#         <Axes: xlabel='NdsCH', ylabel='GATS1i'>,
#         <Axes: xlabel='NdssC', ylabel='GATS1i'>,
# ...

# %%
df.plot.scatter('LC50', 'CIC0')
# Out:
# <Axes: xlabel='LC50', ylabel='CIC0'>

# %%
df.plot.scatter('LC50', 'SM1_Dz(Z)')
# Out:
# <Axes: xlabel='LC50', ylabel='SM1_Dz(Z)'>

# %%
df.plot.scatter('LC50', 'GATS1i')
# Out:
# <Axes: xlabel='LC50', ylabel='GATS1i'>

# %%
df.plot.scatter('LC50', 'NdsCH')
# Out:
# <Axes: xlabel='LC50', ylabel='NdsCH'>

# %%
df.plot.scatter('LC50', 'NdssC')
# Out:
# <Axes: xlabel='LC50', ylabel='NdssC'>

# %%
df.plot.scatter('LC50', 'MLOGP')
# Out:
# <Axes: xlabel='LC50', ylabel='MLOGP'>
